# %% [markdown]
# # Homework 0: Python Installation Guide
#
# **Student Name:**
#
# **Student ID:**
#
# **Date:**
#
# ## Assignment Overview
# This homework assignment will test your understanding of Python installation, environment setup, and basic verification procedures. Complete all exercises and submit your working notebook.
#
# ## Learning Objectives
# - Verify Python installation and version
# - Set up a virtual environment
# - Install required packages
# - Test basic functionality
# - Troubleshoot common issues
#
# ## Instructions
# 1. Complete all exercises in order
# 2. Run all code cells and ensure they execute without errors
# 3. Answer all written questions thoroughly
# 4. Submit your completed notebook
#
# ---
#
# ## Exercise 1: Python Version Verification
#
# **Task:** Check your Python installation and display version information.
#
# **Requirements:**
# - Display Python version
# - Display Python executable path
# - Verify Python version is 3.8 or higher
# - Display platform information

# %%
# Your code here
# Import the sys module to access Python system-specific parameters and functions
import sys
# Import the platform module to access underlying platform's identifying data
import platform

# TODO: Complete the following tasks:
# 1. Print Python version
# 2. Print Python executable path
# 3. Check if Python version is 3.8 or higher
# 4. Print platform information

# Print the Python version string which includes version number and build information
print("Python Version:", {sys.version}) # get python version
# Print a newline character for better formatting, then the Python executable path
print("\nPython Executable:", {sys.executable}) # locate python executable
# Print another newline character, then the platform information (OS, version, architecture)
print("\nPlatform:", platform.platform())
# Print another newline character, then the architecture information (bitness, linkage)
print("\nArchitecture:", platform.architecture())

# Version check
# Get the version info tuple containing major, minor, micro, releaselevel, and serial
version_info = sys.version_info
# Check if major version is 3 or higher AND minor version is 8 or higher
if version_info.major >= 3 and version_info.minor >= 8:
    # Print success message if version is compatible
    print("\n✅ Python version is compatible (3.8+)")
else:
    # Print error message if version is too old
    print("\n❌ Python version is too old. Please upgrade to 3.8 or higher.")
# Out:
# Python Version: {'3.11.13 (main, Jun  5 2025, 08:14:07) [Clang 14.0.6 ]'}
#
# Python Executable: {'/opt/miniconda3/envs/python-course/bin/python'}
#
# Platform: macOS-10.16-x86_64-i386-64bit
#
# Architecture: ('64bit', '')
#
# ✅ Python version is compatible (3.8+)

# %% [markdown]
# **Question 1.1:** What is your Python version and is it compatible with the course requirements?
#
# **Answer:** [Your answer here]

# %% [markdown]
# ---
#
# ## Exercise 2: Virtual Environment Setup
#
# **Task:** Create and activate a virtual environment for this course.
#
# **Requirements:**
# - Create a virtual environment named 'python-course-env'
# - Activate the virtual environment
# - Verify the environment is active
# - Display the Python path in the virtual environment

# %%
# Note: Virtual environment creation should be done in terminal/command prompt
# Run these commands in your terminal:

# Print instructions for creating a virtual environment
print("To create a virtual environment, run these commands in your terminal:")
# Print a newline character for better formatting
print("\n1. Create virtual environment:")
# Print the command to create a virtual environment using the venv module
print("   python -m venv python-course-env")

# Print another newline character for better formatting
print("\n2. Activate virtual environment:")
# Print instructions for Windows users
print("   # On Windows:")
# Print the Windows activation command (note the double backslash for escaping)
print("   python-course-env\\Scripts\\activate")
# Print instructions for macOS/Linux users
print("   # On macOS/Linux:")
# Print the macOS/Linux activation command
print("   source python-course-env/bin/activate")

# Print another newline character for better formatting
print("\n3. Verify activation:")
# Print the command to check Python location on macOS/Linux
print("   which python  # macOS/Linux")
# Print the command to check Python location on Windows
print("   where python  # Windows")

# After activation, run this cell to verify
# Import the sys module to access Python system-specific parameters
import sys
# Print a newline character, then the current Python executable path
print("\nCurrent Python path:", sys.executable)
# Check if 'python-course-env' is in the executable path to verify virtual environment is active
print("Virtual environment active:", 'python-course-env' in sys.executable)
# Out:
# To create a virtual environment, run these commands in your terminal:
#
# 1. Create virtual environment:
#    python -m venv python-course-env
#
# 2. Activate virtual environment:
#    # On Windows:
#    python-course-env\Scripts\activate
#    # On macOS/Linux:
#    source python-course-env/bin/activate
#
# 3. Verify activation:
#    which python  # macOS/Linux
#    where python  # Windows
#
# Current Python path: /opt/miniconda3/envs/python-course/bin/python
# Virtual environment active: False
