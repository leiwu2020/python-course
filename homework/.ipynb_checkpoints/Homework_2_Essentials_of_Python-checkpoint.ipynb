# %% [markdown]
# # Homework 2: Essentials of Python
#
# **Student Name:**
#
# **Student ID:**
#
# **Date:**
#
# ## Assignment Overview
# This homework assignment tests your understanding of advanced Python concepts including data structures, object-oriented programming, file handling, and advanced features.
#
# ## Learning Objectives
# - Master Python data structures (lists, tuples, dictionaries, sets)
# - Implement object-oriented programming concepts
# - Handle file I/O operations
# - Use advanced Python features (list comprehensions, generators)
# - Apply regular expressions and date/time operations
#
# ## Instructions
# 1. Complete all exercises in order
# 2. Run all code cells and ensure they execute without errors
# 3. Answer all written questions thoroughly
# 4. Submit your completed notebook
#
# ---
#
# ## Exercise 1: Data Structures (20 points)
#
# **Task:** Work with Python's built-in data structures and demonstrate their operations.
#
# **Requirements:**
# - Create and manipulate lists, tuples, dictionaries, and sets
# - Demonstrate common operations for each data structure
# - Use list comprehensions and generator expressions
# - Implement data structure transformations

# %%
# TODO: Complete the following tasks

# 1. Lists - Dynamic arrays
# Print a header to indicate the start of the lists section
print("=== LISTS ===")

# Create lists
# Create a list of integers from 1 to 5
numbers = [1, 2, 3, 4, 5]
# Create a list of string fruit names
fruits = ['apple', 'banana', 'cherry', 'date']
# Create a mixed list containing different data types including a nested list
mixed = [1, 'hello', 3.14, True, [1, 2, 3]]

# Print the numbers list using f-string formatting
print(f"Numbers list: {_______}")
# Print the fruits list using f-string formatting
print(f"Fruits list: {_______}")
# Print the mixed list using f-string formatting
print(f"Mixed list: {_______}")

# TODO: List operations
# Print a header for list operations section
print(f"\nList Operations:")
# Get the length of the numbers list using len() function
print(f"Length: {len(_______)}") # get length of the number list
# Access the first element of the numbers list using index 0
print(f"First element: {_______}") # get the first number
# Access the last element of the numbers list using negative index -1
print(f"Last element: {_______}")
# Get a slice of the numbers list from index 1 to 3 (exclusive)
print(f"Slice [1:3]: {_______}")

# List methods
# Add the number 6 to the end of the numbers list using append()
numbers.append(6)
# Print the numbers list after appending 6
print(f"After append(6): {numbers}")

# Insert the value 2.5 at index 2 in the numbers list 
numbers._______(2, 2.5)
# Print the numbers list after inserting 2.5 at index 2
print(f"After insert(2, 2.5): {numbers}")

# Remove the first occurrence of 2.5 from the numbers list
numbers._______(2.5)
# Print the numbers list after removing 2.5
print(f"After remove(2.5): {numbers}")

# Remove and return the last element from the numbers list
popped = numbers._______()
# Print the popped element and the updated numbers list
print(f"Popped element: {popped}, List: {numbers}")

# List comprehensions
# Create a list of squares using list comprehension for numbers 1 to 5
squares = [_______]
# Print the squares list
print(f"Squares: {squares}")

# Create a list of squares for even numbers only using list comprehension with condition
even_squares = [_______]
# Print the even squares list
print(f"Even squares: {even_squares}")

# 2. Tuples - Immutable sequences
# Print a header to indicate the start of the tuples section
print(f"\n=== TUPLES ===")

# Create tuples
# Create a tuple representing x,y coordinates
coordinates = (3, 4)
# Create a tuple representing person information (name, age, job)
person = ('Alice', 25, 'Engineer')
# Create a tuple of color names
colors = ('red', 'green', 'blue')

# Print the coordinates tuple
print(f"Coordinates: {coordinates}")
# Print the person tuple
print(f"Person: {person}")
# Print the colors tuple
print(f"Colors: {colors}")

# TODO: Tuple operations
# Print a header for tuple operations section
print(f"\nTuple Operations:")
# Get the length of the coordinates tuple using len() function
print(f"Length: {_______}")
# Access the first element of the coordinates tuple using index 0
print(f"First element: {_______}")
# Access the last element of the coordinates tuple using negative index -1
print(f"Last element: {_______}")

# Tuple unpacking
# Unpack the person tuple into three separate variables
name, age, job = person
# Print the unpacked values with descriptive labels
print(f"Unpacked - Name: {name}, Age: {age}, Job: {job}")

# Tuple methods
# Count how many times 'red' appears in the colors tuple using count()
print(f"Count of 'red' in colors: {_______}")
# Find the index of 'green' in the colors tuple using index()
print(f"Index of 'green' in colors: {_______}")

# 3. Dictionaries - Key-value pairs
# Print a header to indicate the start of the dictionaries section
print(f"\n=== DICTIONARIES ===")

# Create dictionaries
# Create a dictionary representing student information with nested list for grades
student = {
    'name': 'Bob',
    'age': 22,
    'major': 'Computer Science',
    'grades': [85, 92, 78, 96]
}

# Create a dictionary using dict() constructor with keyword arguments
scores = dict(math=95, science=87, english=92)

# Print the student dictionary
print(f"Student: {student}")
# Print the scores dictionary
print(f"Scores: {scores}")

# TODO: Dictionary operations
# Print a header for dictionary operations section
print(f"\nDictionary Operations:")
# Access the 'name' key from the student dictionary using square bracket notation
print(f"Student name: {_______}")
# Access the 'age' key from the student dictionary using get() method with default value
print(f"Student age: {_______}")

# Add new key-value pair
# Add a new key 'year' with value 'Senior' to the student dictionary
student['year'] = 'Senior'
# Print the student dictionary after adding the year
print(f"After adding year: {student}")

# Update existing value
# Update the 'age' key in the student dictionary to 23
student['age'] = 23
# Print the student dictionary after updating the age
print(f"After updating age: {student}")

# Dictionary methods
# Get all keys from the student dictionary and convert to list
print(f"Keys: {_______}")
# Get all values from the student dictionary and convert to list
print(f"Values: {_______}")
# Get all key-value pairs from the student dictionary and convert to list
print(f"Items: {_______}")

# Dictionary comprehension
# Create a new dictionary with squared scores using dictionary comprehension
squared_scores = {subject: score**2 for subject, score in scores.items()}
# Print the squared scores dictionary
print(f"Squared scores: {squared_scores}")

# 4. Sets - Unique elements
# Print a header to indicate the start of the sets section
print(f"\n=== SETS ===")

# Create sets
# Create a set of integers from 1 to 5
numbers_set = {1, 2, 3, 4, 5}
# Create a set of fruit names
fruits_set = {'apple', 'banana', 'cherry', 'date'}
# Create a mixed set containing different data types
mixed_set = {1, 'hello', 3.14, True}

# Print the numbers set
print(f"Numbers set: {numbers_set}")
# Print the fruits set
print(f"Fruits set: {fruits_set}")
# Print the mixed set
print(f"Mixed set: {mixed_set}")

# TODO: Set operations
# Print a header for set operations section
print(f"\nSet Operations:")
# Get the length of the numbers_set using len() function
print(f"Length: {_______}")
# Check if the value 3 is in the numbers_set using 'in' operator
print(f"Is 3 in set: {_______}")

# Set methods
# Add the number 6 to the numbers_set 
numbers_set._______(6)
# Print the numbers_set after adding 6
print(f"After add(6): {numbers_set}")

# Remove the number 6 from the numbers_set 
numbers_set._______(6)
# Print the numbers_set after removing
print(f"After remove(6): {numbers_set}")

# Set operations
# Create two sets for demonstrating set operations
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# Print both sets
print(f"Set1: {set1}")
print(f"Set2: {set2}")
# Calculate the union of set1 and set2 using | operator
print(f"Union: {_______}")
# Calculate the intersection of set1 and set2 using & operator
print(f"Intersection: {_______}")
# Calculate the difference of set1 and set2 (elements in set1 but not in set2) using - operator
print(f"Difference: {_______}")
# Calculate the symmetric difference of set1 and set2 using ^ operator
print(f"Symmetric difference: {_______}")

# 5. Data structure transformations
# Print a header to indicate the start of data structure transformations section
print(f"\n=== DATA STRUCTURE TRANSFORMATIONS ===")

# List to set (removes duplicates)
# Create a list with duplicate numbers
numbers_with_duplicates = [1, 2, 2, 3, 3, 3, 4, 5]
# Convert the list to a set to remove duplicates, then back to a list
unique_numbers = _______
# Print the original list with duplicates
print(f"Original: {numbers_with_duplicates}")
# Print the list with duplicates removed
print(f"Unique: {unique_numbers}")

# Dictionary to list of tuples
# Convert the student dictionary to a list of key-value tuples using items()
student_items = _______
# Print the student dictionary as a list of tuples
print(f"Student as list of tuples: {student_items}")

# List of tuples to dictionary
# Create a list of tuples representing key-value pairs
pairs = [('a', 1), ('b', 2), ('c', 3)]
# Convert the list of tuples to a dictionary using dict() constructor
pairs_dict = _______
# Print the list of tuples as a dictionary
print(f"Pairs as dictionary: {pairs_dict}")

# TODO: Create a nested data structure
# Create a nested dictionary containing students list, course info, and instructor
nested_data = {
    'students': [
        {'name': 'Alice', 'grades': [85, 92, 78]},
        {'name': 'Bob', 'grades': [90, 88, 95]},
        {'name': 'Charlie', 'grades': [75, 82, 88]}
    ],
    'course': 'Python Programming',
    'instructor': 'Dr. Smith'
}

# Print a header for the nested data structure
print(f"\nNested data structure:")
# Access and print the 'course' key from the nested_data dictionary
print(f"Course: {_______}")
# Access and print the 'instructor' key from the nested_data dictionary
print(f"Instructor: {_______}")
# Access and print the 'students' key from the nested_data dictionary
print(f"Students: {_______}")

# Access nested data
# Get the first student from the students list (index 0)
first_student = _______
# Print the first student dictionary
print(f"First student: {first_student}")
# Access the 'name' key from the first student dictionary
print(f"First student's name: {_______}")
# Access the 'grades' key from the first student dictionary
print(f"First student's grades: {_______}")
