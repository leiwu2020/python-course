# %% [markdown]
# # Homework 6: Pandas DataFrame II
#
# **Student Name:**
#
# **Student ID:**
#
# **Date:**
#
# ## Assignment Overview
# This homework assignment tests your understanding of advanced Pandas DataFrame operations including grouping, merging, and data transformation.
#
# ## Learning Objectives
# - Master DataFrame grouping and aggregation
# - Perform data merging and joining
# - Use pivot tables and reshaping
# - Apply advanced data transformation techniques
# - Handle time series data
#
# ## Instructions
# 1. Complete all exercises in order
# 2. Run all code cells and ensure they execute without errors
# 3. Answer all written questions thoroughly
# 4. Submit your completed notebook
#
# ---
#
# ## Exercise 1: Grouping and Aggregation
#
# **Task:** Perform grouping and aggregation operations on DataFrames.
#
# **Requirements:**
# - Group data by different criteria
# - Apply aggregation functions
# - Use groupby operations
# - Demonstrate advanced grouping techniques

# %%
# TODO: Complete the following tasks

# Import pandas library for data manipulation and analysis
import pandas as pd
# Import numpy library for numerical operations
import numpy as np
# Import matplotlib for plotting
import matplotlib.pyplot as plt
# Import seaborn for statistical data visualization
import seaborn as sns

# Set random seed for reproducible results
np.random.seed(__________) # set random seed to 42

# 1. Create sample datasets for analysis
print("=== CREATING SAMPLE DATASETS ===")

# Create sales data dictionary with various fields
sales_data = {
    'Date': pd.date_range('2023-01-01', periods=__________, freq='D'), # create 100 days of dates
    'Product': np.random.choice(['Laptop', 'Phone', 'Tablet', 'Headphones'], __________), # choose 100 random products
    'Category': np.random.choice(['Electronics', 'Accessories'], __________), # choose 100 random categories
    'Region': np.random.choice(['North', 'South', 'East', 'West'], __________), # choose 100 random regions
    'Salesperson': np.random.choice(['Alice', 'Bob', 'Charlie', 'Diana'], __________), # choose 100 random salespeople
    'Quantity': np.random.randint(__________, __________, __________), # generate 100 random quantities between 1 and 10
    'Price': np.random.uniform(__________, __________, __________), # generate 100 random prices between 50 and 1000
    'Customer_Rating': np.random.uniform(__________, __________, __________) # generate 100 random ratings between 3.0 and 5.0
}

# Create DataFrame from sales data dictionary
df_sales = pd.DataFrame(sales_data)
# Calculate revenue by multiplying quantity and price
df_sales['Revenue'] = df_sales['__________'] * df_sales['__________'] # multiply 'Quantity' and 'Price'

print(f"Sales DataFrame shape: {df_sales.shape}")
print(f"\nFirst 5 rows:")
print(df_sales.head())

# Create employee data dictionary
employee_data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Department': ['Sales', 'Sales', 'Marketing', 'Sales'],
    'Experience_Years': [5, 3, 7, 2],
    'Salary': [75000, 65000, 80000, 55000],
    'Hire_Date': pd.to_datetime(['2018-03-15', '2020-06-20', '2016-01-10', '2021-09-05'])
}

# Create DataFrame from employee data dictionary
df_employees = pd.DataFrame(employee_data)

print(f"\nEmployee DataFrame:")
print(df_employees)

# 2. Basic Grouping Operations
print(f"\n=== BASIC GROUPING OPERATIONS ===")

# TODO: Group by single column
print("Grouping by Product:")
# Group the sales DataFrame by the 'Product' column
product_groups = df_sales.groupby('__________') # group by 'Product'
print(f"Number of groups: {len(product_groups)}")
print(f"Group names: {list(product_groups.groups.keys())}")

# Basic aggregation
# Apply aggregation functions to grouped data
product_summary = product_groups.agg({
    'Quantity': '__________', # use 'sum' for quantity
    'Revenue': '__________', # use 'sum' for revenue
    'Customer_Rating': '__________' # use 'mean' for customer rating
}).round(2)

print(f"\nProduct Summary:")
print(product_summary)

# TODO: Group by multiple columns
print(f"\nGrouping by Product and Region:")
# Group by multiple columns using a list
multi_groups = df_sales.groupby(['__________', '__________']) # group by 'Product' and 'Region'
multi_summary = multi_groups.agg({
    'Quantity': 'sum',
    'Revenue': 'sum',
    'Customer_Rating': 'mean'
}).round(2)

print(f"Multi-group Summary (first 10 rows):")
print(multi_summary.head(10))

# 3. Advanced Aggregation Functions
print(f"\n=== ADVANCED AGGREGATION FUNCTIONS ===")

# TODO: Custom aggregation functions
def custom_stats(group):
    return pd.Series({
        'count': len(group),
        'total_revenue': group['Revenue'].sum(),
        'avg_rating': group['Customer_Rating'].mean(),
        'max_quantity': group['Quantity'].max(),
        'min_price': group['Price'].min()
    })

# Apply custom aggregation
# Group by 'Region' and apply the custom_stats function
region_stats = df_sales.groupby('__________').apply(custom_stats).round(2) # group by 'Region'
print(f"Custom Statistics by Region:")
print(region_stats)

# TODO: Multiple aggregation functions
print(f"\nMultiple Aggregation Functions:")
# Define multiple aggregation functions for each column
agg_functions = {
    'Quantity': ['__________', '__________', '__________'], # use 'sum', 'mean', 'std'
    'Revenue': ['__________', '__________', '__________'], # use 'sum', 'mean', 'max'
    'Customer_Rating': ['__________', '__________', '__________'] # use 'mean', 'min', 'max'
}

# Apply multiple aggregation functions grouped by 'Category'
multi_agg = df_sales.groupby('__________').agg(agg_functions).round(2) # group by 'Category'
print(multi_agg)

# 4. Groupby with Transform and Filter
print(f"\n=== GROUPBY WITH TRANSFORM AND FILTER ===")

# TODO: Transform operations
# Add a new column with total revenue per product group
df_sales['Revenue_Per_Group'] = df_sales.groupby('__________')['__________'].transform('__________') # group by 'Product', transform 'Revenue' with 'sum'
# Add a new column with average rating per region
df_sales['Avg_Rating_Per_Region'] = df_sales.groupby('__________')['__________'].transform('__________') # group by 'Region', transform 'Customer_Rating' with 'mean'

print(f"DataFrame with transform operations (first 5 rows):")
print(df_sales[['Product', 'Revenue', 'Revenue_Per_Group', 'Region', 'Customer_Rating', 'Avg_Rating_Per_Region']].head())

# TODO: Filter operations
def high_revenue_groups(group):
    return group['Revenue'].sum() > __________ # return True if sum > 5000

# Filter groups where total revenue is greater than 5000
high_revenue = df_sales.groupby('__________').filter(high_revenue_groups) # group by 'Product'
print(f"\nProducts with total revenue > 5000:")
print(f"Unique products: {high_revenue['Product'].unique()}")
print(f"Number of records: {len(high_revenue)}")

# 5. Pivot Tables
print(f"\n=== PIVOT TABLES ===")

# TODO: Create pivot tables
# Create a pivot table showing quantity by product and region
pivot_quantity = df_sales.pivot_table(
    values='__________', # use 'Quantity' as values
    index='__________', # use 'Product' as index
    columns='__________', # use 'Region' as columns
    aggfunc='__________', # use 'sum' as aggregation function
    fill_value=__________ # use 0 as fill value
)

print(f"Quantity by Product and Region:")
print(pivot_quantity)

# TODO: Multi-level pivot table
# Create a multi-level pivot table with multiple values and indices
pivot_multi = df_sales.pivot_table(
    values=['__________', '__________'], # use 'Quantity' and 'Revenue' as values
    index=['__________', '__________'], # use 'Product' and 'Category' as index
    columns='__________', # use 'Region' as columns
    aggfunc={'Quantity': 'sum', 'Revenue': 'mean'},
    fill_value=__________ # use 0 as fill value
)

print(f"\nMulti-level Pivot Table (first 5 rows):")
print(pivot_multi.head())

# 6. Data Merging and Joining
print(f"\n=== DATA MERGING AND JOINING ===")

# TODO: Merge sales data with employee data
# First, create a mapping from salesperson to employee data
# Set 'Name' as index and select specific columns
salesperson_mapping = df_employees.set_index('__________')[['Department', 'Experience_Years', 'Salary']] # use 'Name' as index
# Merge sales data with employee data using left join
df_sales_merged = df_sales.merge(salesperson_mapping, left_on='__________', right_index=True, how='__________') # use 'Salesperson' as left_on, 'left' as how

print(f"Sales data merged with employee data (first 5 rows):")
print(df_sales_merged[['Salesperson', 'Department', 'Experience_Years', 'Salary', 'Revenue']].head())

# TODO: Different types of joins
# Create a small dataset for demonstration
df_products = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Headphones', 'Mouse'],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories', 'Accessories'],
    'Cost': [400, 300, 200, 50, 25]
})

print(f"\nProducts DataFrame:")
print(df_products)

# Inner join - only matching records from both DataFrames
inner_join = df_sales.merge(df_products, on='__________', how='__________') # use 'Product' as on, 'inner' as how
print(f"\nInner join shape: {inner_join.shape}")

# Left join - all records from left DataFrame
left_join = df_sales.merge(df_products, on='__________', how='__________') # use 'Product' as on, 'left' as how
print(f"Left join shape: {left_join.shape}")

# Right join - all records from right DataFrame
right_join = df_sales.merge(df_products, on='__________', how='__________') # use 'Product' as on, 'right' as how
print(f"Right join shape: {right_join.shape}")

# 7. Data Reshaping
print(f"\n=== DATA RESHAPING ===")

# TODO: Melt operation
# Transform wide format to long format
melted_data = df_sales.melt(
    id_vars=['__________', '__________', '__________'], # use 'Date', 'Product', 'Region' as id_vars
    value_vars=['__________', '__________', '__________'], # use 'Quantity', 'Revenue', 'Customer_Rating' as value_vars
    var_name='__________', # use 'Metric' as var_name
    value_name='__________' # use 'Value' as value_name
)

print(f"Melted data (first 10 rows):")
print(melted_data.head(10))

# TODO: Pivot operation (reverse of melt)
# Transform long format back to wide format
pivoted_data = melted_data.pivot_table(
    index=['__________', '__________', '__________'], # use 'Date', 'Product', 'Region' as index
    columns='__________', # use 'Metric' as columns
    values='__________', # use 'Value' as values
    fill_value=__________ # use 0 as fill_value
).reset_index()

print(f"\nPivoted data (first 5 rows):")
print(pivoted_data.head())

# 8. Time Series Operations
print(f"\n=== TIME SERIES OPERATIONS ===")

# TODO: Set date as index
# Set the 'Date' column as the index for time series operations
df_sales_time = df_sales.set_index('__________') # use 'Date' as index
print(f"DataFrame with Date as index:")
print(df_sales_time.head())

# TODO: Resample by different time periods
# Resample revenue data by different time periods
daily_revenue = df_sales_time['Revenue'].resample('__________').sum() # use 'D' for daily
weekly_revenue = df_sales_time['Revenue'].resample('__________').sum() # use 'W' for weekly
monthly_revenue = df_sales_time['Revenue'].resample('__________').sum() # use 'M' for monthly

print(f"\nDaily Revenue (first 5 days):")
print(daily_revenue.head())

print(f"\nWeekly Revenue:")
print(weekly_revenue.head())

print(f"\nMonthly Revenue:")
print(monthly_revenue.head())

# TODO: Rolling window operations
# Calculate rolling averages with different window sizes
df_sales_time['Revenue_7day_avg'] = df_sales_time['Revenue'].rolling(window=__________).mean() # use 7 for 7-day window
df_sales_time['Revenue_30day_avg'] = df_sales_time['Revenue'].rolling(window=__________).mean() # use 30 for 30-day window

print(f"\nDataFrame with rolling averages (last 5 rows):")
print(df_sales_time[['Revenue', 'Revenue_7day_avg', 'Revenue_30day_avg']].tail())

# %% [markdown]
# **Question 1.1:** What is the difference between `groupby().agg()` and `groupby().apply()`?
#
# **Answer:** [Your answer here]
#
# **Question 1.2:** When would you use `transform()` vs `filter()` in groupby operations?
#
# **Answer:** [Your answer here]
#
# **Question 1.3:** What are the advantages of using pivot tables over groupby operations?
#
# **Answer:** [Your answer here]

# %% [markdown]
# ---
#
# ## Exercise 2: Data Merging and Joining
#
# **Task:** Perform various data merging and joining operations.
#
# **Requirements:**
# - Merge DataFrames using different join types
# - Handle missing values in merged data
# - Use different merge keys and strategies
# - Demonstrate complex merging scenarios

# %%
# TODO: Complete the following merging exercises

# 1. Create additional datasets for merging
print("=== CREATING DATASETS FOR MERGING ===")

# Customer data dictionary with customer information
customer_data = {
    'Customer_ID': [1, 2, 3, 4, 5, 6],
    'Name': ['Alice Johnson', 'Bob Smith', 'Charlie Brown', 'Diana Prince', 'Eve Wilson', 'Frank Miller'],
    'Email': ['alice@email.com', 'bob@email.com', 'charlie@email.com', 'diana@email.com', 'eve@email.com', 'frank@email.com'],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia'],
    'Registration_Date': pd.to_datetime(['2022-01-15', '2022-03-20', '2022-02-10', '2022-04-05', '2022-05-12', '2022-06-18'])
}

# Create customers DataFrame
df_customers = pd.DataFrame(__________) # use customer_data

# Order data dictionary with order information
order_data = {
    'Order_ID': [101, 102, 103, 104, 105, 106, 107, 108],
    'Customer_ID': [1, 2, 1, 3, 4, 2, 5, 6],
    'Product': ['Laptop', 'Phone', 'Tablet', 'Headphones', 'Laptop', 'Phone', 'Tablet', 'Headphones'],
    'Order_Date': pd.to_datetime(['2023-01-15', '2023-01-20', '2023-02-01', '2023-02-10', '2023-02-15', '2023-03-01', '2023-03-10', '2023-03-20']),
    'Amount': [1200, 800, 600, 150, 1100, 750, 550, 140]
}

# Create orders DataFrame
df_orders = pd.DataFrame(__________) # use order_data

# Product details dictionary with product information
product_details = {
    'Product': ['Laptop', 'Phone', 'Tablet', 'Headphones', 'Mouse', 'Keyboard'],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories', 'Accessories', 'Accessories'],
    'Brand': ['TechCorp', 'PhoneInc', 'TabletPro', 'SoundMax', 'ClickTech', 'TypeFast'],
    'Warranty_Years': [2, 1, 2, 1, 1, 1],
    'Weight_kg': [2.5, 0.2, 0.8, 0.3, 0.1, 0.5]
}

# Create products DataFrame
df_products = pd.DataFrame(__________) # use product_details

print(f"Customers DataFrame:")
print(df_customers)
print(f"\nOrders DataFrame:")
print(df_orders)
print(f"\nProducts DataFrame:")
print(df_products)

# 2. Basic Merging Operations
print(f"\n=== BASIC MERGING OPERATIONS ===")

# TODO: Inner join
print("Inner Join - Customers and Orders:")
# Merge customers and orders using inner join on Customer_ID
inner_merge = df_customers.merge(df_orders, on='__________', how='__________') # use 'Customer_ID' as on, 'inner' as how
print(f"Shape: {inner_merge.shape}")
print(inner_merge.head())

# TODO: Left join
print(f"\nLeft Join - Customers and Orders:")
# Merge customers and orders using left join on Customer_ID
left_merge = df_customers.merge(df_orders, on='__________', how='__________') # use 'Customer_ID' as on, 'left' as how
print(f"Shape: {left_merge.shape}")
print(f"Missing values in Order_ID: {left_merge['Order_ID'].isnull().sum()}")

# TODO: Right join
print(f"\nRight Join - Orders and Customers:")
# Merge orders and customers using right join on Customer_ID
right_merge = df_orders.merge(df_customers, on='__________', how='__________') # use 'Customer_ID' as on, 'right' as how
print(f"Shape: {right_merge.shape}")

# TODO: Outer join
print(f"\nOuter Join - Customers and Orders:")
# Merge customers and orders using outer join on Customer_ID
outer_merge = df_customers.merge(df_orders, on='__________', how='__________') # use 'Customer_ID' as on, 'outer' as how
print(f"Shape: {outer_merge.shape}")
print(f"Missing values in Customer_ID: {outer_merge['Customer_ID'].isnull().sum()}")

# 3. Advanced Merging Scenarios
print(f"\n=== ADVANCED MERGING SCENARIOS ===")

# TODO: Merge with different column names
print("Merging with different column names:")
# Rename Product column to Product_Name in orders DataFrame
df_orders_renamed = df_orders.rename(columns={'Product': '__________'}) # rename 'Product' to 'Product_Name'
# Merge using different column names
merge_different_cols = df_orders_renamed.merge(
    df_products, 
    left_on='__________', # use 'Product_Name' as left_on
    right_on='__________', # use 'Product' as right_on
    how='__________' # use 'left' as how
)
print(f"Shape: {merge_different_cols.shape}")
print(merge_different_cols[['Order_ID', 'Product_Name', 'Brand', 'Category']].head())

# TODO: Merge with multiple keys
print(f"\nMerging with multiple keys:")
# Create a dataset with multiple keys
df_orders_multi = df_orders.copy()
# Extract month from Order_Date
df_orders_multi['Order_Month'] = df_orders_multi['Order_Date'].dt.__________ # use 'month'

df_customers_multi = df_customers.copy()
# Extract month from Registration_Date
df_customers_multi['Registration_Month'] = df_customers_multi['Registration_Date'].dt.__________ # use 'month'

# Merge using multiple keys
multi_key_merge = df_orders_multi.merge(
    df_customers_multi, 
    on=['__________', '__________'], # use 'Customer_ID' and 'Order_Month'
    how='__________' # use 'left' as how
)
print(f"Shape: {multi_key_merge.shape}")
print(multi_key_merge[['Order_ID', 'Customer_ID', 'Order_Month', 'Name', 'City']].head())

# 4. Handling Missing Values in Merged Data
print(f"\n=== HANDLING MISSING VALUES ===")

# TODO: Identify and handle missing values
print("Missing values analysis:")
print(f"Left merge missing values:")
print(left_merge.isnull().sum())

# TODO: Fill missing values
left_merge_filled = left_merge.copy()
# Fill missing Order_ID values with 0
left_merge_filled['Order_ID'] = left_merge_filled['Order_ID'].fillna(__________) # use 0
# Fill missing Product values with 'No Order'
left_merge_filled['Product'] = left_merge_filled['Product'].fillna('__________') # use 'No Order'
# Fill missing Amount values with 0
left_merge_filled['Amount'] = left_merge_filled['Amount'].fillna(__________) # use 0

print(f"\nAfter filling missing values:")
print(left_merge_filled.isnull().sum())

# 5. Complex Merging Scenarios
print(f"\n=== COMPLEX MERGING SCENARIOS ===")

# TODO: Merge multiple DataFrames
print("Merging multiple DataFrames:")
# First merge: orders with customers
orders_customers = df_orders.merge(df_customers, on='__________', how='__________') # use 'Customer_ID' as on, 'left' as how

# Second merge: add product details
complete_data = orders_customers.merge(df_products, on='__________', how='__________') # use 'Product' as on, 'left' as how

print(f"Complete merged data shape: {complete_data.shape}")
print(f"Columns: {list(complete_data.columns)}")
print(complete_data.head())

# TODO: Merge with aggregation
print(f"\nMerging with aggregation:")
# Aggregate orders by customer
customer_totals = df_orders.groupby('__________').agg({ # use 'Customer_ID'
    'Order_ID': '__________', # use 'count'
    'Amount': ['__________', '__________', '__________'] # use 'sum', 'mean', 'max'
}).round(2)

# Flatten column names
customer_totals.columns = ['_'.join(col).strip() for col in customer_totals.columns]
customer_totals = customer_totals.reset_index()

# Merge with customer data
customer_summary = df_customers.merge(customer_totals, on='__________', how='__________') # use 'Customer_ID' as on, 'left' as how
print(f"Customer summary with order statistics:")
print(customer_summary)

# 6. Merge Performance and Best Practices
print(f"\n=== MERGE PERFORMANCE AND BEST PRACTICES ===")

# TODO: Demonstrate merge performance
import time

# Large dataset simulation
large_customers = pd.concat([df_customers] * 1000, ignore_index=True)
large_orders = pd.concat([df_orders] * 1000, ignore_index=True)

print(f"Large datasets created:")
print(f"Customers shape: {large_customers.shape}")
print(f"Orders shape: {large_orders.shape}")

# Time the merge operation
start_time = time.time()
large_merge = large_customers.merge(large_orders, on='Customer_ID', how='inner')
end_time = time.time()

print(f"Merge completed in {end_time - start_time:.4f} seconds")
print(f"Result shape: {large_merge.shape}")

# TODO: Memory usage optimization
print(f"\nMemory optimization tips:")
print(f"Original customers memory usage: {df_customers.memory_usage(deep=True).sum() / 1024:.2f} KB")
print(f"Original orders memory usage: {df_orders.memory_usage(deep=True).sum() / 1024:.2f} KB")

# Convert to appropriate data types
df_customers_optimized = df_customers.copy()
df_customers_optimized['Customer_ID'] = df_customers_optimized['Customer_ID'].astype('int32')
df_customers_optimized['Name'] = df_customers_optimized['Name'].astype('category')

print(f"Optimized customers memory usage: {df_customers_optimized.memory_usage(deep=True).sum() / 1024:.2f} KB")

# %% [markdown]
# ---
#
# ## Exercise 3: Data Visualization and Analysis
#
# **Task:** Create visualizations to analyze the grouped and merged data.
#
# **Requirements:**
# - Create charts for grouped data
# - Visualize merged data relationships
# - Use appropriate plot types for different data types
# - Customize plots for better presentation

# %%
# TODO: Complete the following visualization exercises

# 1. Set up plotting style
# Set matplotlib style for better-looking plots
plt.style.use('__________') # use 'seaborn-v0_8'
# Set seaborn color palette
sns.set_palette("__________") # use "husl"

# 2. Visualize Grouped Data
print("=== VISUALIZING GROUPED DATA ===")

# TODO: Create subplots for different analyses
# Create a 2x2 subplot layout with specified figure size
fig, axes = plt.subplots(__________, __________, figsize=(__________, __________)) # use 2, 2, 15, 12

# Revenue by Product
# Group sales data by Product and sum Revenue, sort in ascending order
product_revenue = df_sales.groupby('__________')['__________'].sum().sort_values(ascending=__________) # use 'Product', 'Revenue', True
# Create horizontal bar chart
axes[0, 0].barh(product_revenue.index, product_revenue.values, color='__________') # use 'skyblue'
axes[0, 0].set_title('Total Revenue by Product')
axes[0, 0].set_xlabel('Revenue ($)')
axes[0, 0].grid(True, alpha=__________) # use 0.3

# Average Rating by Region
# Group sales data by Region and calculate mean Customer_Rating, sort in descending order
region_rating = df_sales.groupby('__________')['__________'].mean().sort_values(ascending=__________) # use 'Region', 'Customer_Rating', False
# Create vertical bar chart
axes[0, 1].bar(region_rating.index, region_rating.values, color='__________') # use 'lightcoral'
axes[0, 1].set_title('Average Customer Rating by Region')
axes[0, 1].set_ylabel('Average Rating')
axes[0, 1].set_ylim(0, __________) # use 5
axes[0, 1].grid(True, alpha=0.3)

# Quantity distribution by Category
# Group sales data by Category and sum Quantity
category_quantity = df_sales.groupby('__________')['__________'].sum() # use 'Category', 'Quantity'
# Create pie chart
axes[1, 0].pie(category_quantity.values, labels=category_quantity.index, autopct='%1.1f%%', startangle=__________) # use 90
axes[1, 0].set_title('Quantity Distribution by Category')

# Revenue trend over time
# Group sales data by Date and sum Revenue
daily_revenue = df_sales.groupby('__________')['__________'].sum() # use 'Date', 'Revenue'
# Create line plot
axes[1, 1].plot(daily_revenue.index, daily_revenue.values, marker='__________', linewidth=__________, markersize=__________) # use 'o', 2, 4
axes[1, 1].set_title('Daily Revenue Trend')
axes[1, 1].set_xlabel('Date')
axes[1, 1].set_ylabel('Revenue ($)')
axes[1, 1].tick_params(axis='x', rotation=__________) # use 45
axes[1, 1].grid(True, alpha=0.3)

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()

# 3. Visualize Merged Data
print("\n=== VISUALIZING MERGED DATA ===")

# TODO: Create visualizations for merged data
# Create another 2x2 subplot layout
fig, axes = plt.subplots(__________, __________, figsize=(__________, __________)) # use 2, 2, 15, 12

# Customer order count
# Group complete data by Name and count Order_ID, sort in ascending order
customer_orders = complete_data.groupby('__________')['__________'].count().sort_values(ascending=__________) # use 'Name', 'Order_ID', True
# Create horizontal bar chart
axes[0, 0].barh(customer_orders.index, customer_orders.values, color='__________') # use 'lightgreen'
axes[0, 0].set_title('Number of Orders by Customer')
axes[0, 0].set_xlabel('Number of Orders')
axes[0, 0].grid(True, alpha=0.3)

# Revenue by City
# Group complete data by City and sum Amount, sort in descending order
city_revenue = complete_data.groupby('__________')['__________'].sum().sort_values(ascending=__________) # use 'City', 'Amount', False
# Create vertical bar chart
axes[0, 1].bar(city_revenue.index, city_revenue.values, color='__________') # use 'orange'
axes[0, 1].set_title('Total Revenue by City')
axes[0, 1].set_ylabel('Revenue ($)')
axes[0, 1].tick_params(axis='x', rotation=45)
axes[0, 1].grid(True, alpha=0.3)

# Product performance by brand
# Group complete data by Brand and aggregate Amount with sum and count
brand_performance = complete_data.groupby('__________')['__________'].agg(['__________', '__________']).reset_index() # use 'Brand', 'Amount', 'sum', 'count'
# Calculate average amount per order
brand_performance['avg_amount'] = brand_performance['__________'] / brand_performance['__________'] # use 'sum', 'count'

# Create scatter plot
scatter = axes[1, 0].scatter(brand_performance['count'], brand_performance['avg_amount'], 
                            s=brand_performance['sum']/__________, alpha=__________, c=brand_performance['sum'], # use 10, 0.7
                            cmap='__________') # use 'viridis'
axes[1, 0].set_title('Brand Performance: Orders vs Average Amount')
axes[1, 0].set_xlabel('Number of Orders')
axes[1, 0].set_ylabel('Average Amount per Order ($)')
axes[1, 0].grid(True, alpha=0.3)

# Add colorbar
cbar = plt.colorbar(scatter, ax=axes[1, 0])
cbar.set_label('Total Revenue ($)')

# Customer registration timeline
# Set Registration_Date as index, resample by month, get size, and calculate cumulative sum
customer_timeline = df_customers.set_index('__________').resample('__________').size().cumsum() # use 'Registration_Date', 'M'
# Create line plot
axes[1, 1].plot(customer_timeline.index, customer_timeline.values, marker='__________', linewidth=__________, markersize=__________) # use 'o', 2, 6
axes[1, 1].set_title('Cumulative Customer Registrations')
axes[1, 1].set_xlabel('Date')
axes[1, 1].set_ylabel('Cumulative Customers')
axes[1, 1].tick_params(axis='x', rotation=45)
axes[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# 4. Advanced Visualizations
print("\n=== ADVANCED VISUALIZATIONS ===")

# TODO: Create heatmap for correlation analysis
plt.figure(figsize=(__________, __________)) # use 12, 8

# Calculate correlation matrix for numerical columns
# Select only numerical columns from complete_data
numerical_cols = complete_data.select_dtypes(include=[__________]).columns # use np.number
# Calculate correlation matrix
correlation_matrix = complete_data[numerical_cols].corr()

# Create heatmap
sns.heatmap(correlation_matrix, annot=__________, cmap='__________', center=__________, # use True, 'coolwarm', 0
            square=__________, linewidths=__________, cbar_kws={"shrink": __________}) # use True, 0.5, 0.8
plt.title('Correlation Matrix of Numerical Variables')
plt.tight_layout()
plt.show()

# TODO: Create box plot for product analysis
plt.figure(figsize=(__________, __________)) # use 12, 6
# Create box plot with Product on x-axis, Amount on y-axis, and Category as hue
sns.boxplot(data=complete_data, x='__________', y='__________', hue='__________') # use 'Product', 'Amount', 'Category'
plt.title('Product Amount Distribution by Category')
plt.xlabel('Product')
plt.ylabel('Amount ($)')
plt.xticks(rotation=__________) # use 45
plt.legend(title='Category')
plt.tight_layout()
plt.show()

# TODO: Create time series analysis
plt.figure(figsize=(__________, __________)) # use 15, 8

# Create time series data
# Set Order_Date as index, resample by week, and aggregate multiple columns
time_series_data = complete_data.set_index('__________').resample('__________').agg({ # use 'Order_Date', 'W'
    'Amount': ['__________', '__________', '__________'], # use 'sum', 'mean', 'count'
    'Customer_Rating': '__________' # use 'mean'
}).round(2)

# Flatten column names
time_series_data.columns = ['_'.join(col).strip() for col in time_series_data.columns]

# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(__________, __________, figsize=(__________, __________)) # use 3, 1, 15, 12

# Weekly revenue
ax1.plot(time_series_data.index, time_series_data['Amount_sum'], marker='__________', linewidth=__________, color='__________') # use 'o', 2, 'blue'
ax1.set_title('Weekly Total Revenue')
ax1.set_ylabel('Revenue ($)')
ax1.grid(True, alpha=0.3)

# Weekly average amount
ax2.plot(time_series_data.index, time_series_data['Amount_mean'], marker='__________', linewidth=__________, color='__________') # use 's', 2, 'green'
ax2.set_title('Weekly Average Amount per Order')
ax2.set_ylabel('Average Amount ($)')
ax2.grid(True, alpha=0.3)

# Weekly order count
ax3.plot(time_series_data.index, time_series_data['Amount_count'], marker='__________', linewidth=__________, color='__________') # use '^', 2, 'red'
ax3.set_title('Weekly Order Count')
ax3.set_xlabel('Date')
ax3.set_ylabel('Number of Orders')
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# 5. Interactive Analysis
print("\n=== INTERACTIVE ANALYSIS ===")

# TODO: Create summary statistics
print("Summary Statistics for Complete Dataset:")
# Calculate and display total revenue
print(f"Total Revenue: ${complete_data['Amount'].sum():,.2f}")
# Calculate and display average order amount
print(f"Average Order Amount: ${complete_data['Amount'].mean():.2f}")
# Calculate and display total number of unique orders
print(f"Total Orders: {complete_data['Order_ID'].nunique()}")
# Calculate and display total number of unique customers
print(f"Total Customers: {complete_data['Customer_ID'].nunique()}")
# Calculate and display average customer rating
print(f"Average Customer Rating: {complete_data['Customer_Rating'].mean():.2f}")

# TODO: Top performers analysis
print(f"\nTop 5 Customers by Revenue:")
# Group by Name, sum Amount, sort in descending order, take top 5
top_customers = complete_data.groupby('__________')['__________'].sum().sort_values(ascending=__________).head(__________) # use 'Name', 'Amount', False, 5
# Loop through and display top customers
for i, (name, amount) in enumerate(top_customers.items(), 1):
    print(f"{i}. {name}: ${amount:,.2f}")

print(f"\nTop 5 Products by Revenue:")
# Group by Product, sum Amount, sort in descending order, take top 5
top_products = complete_data.groupby('__________')['__________'].sum().sort_values(ascending=__________).head(__________) # use 'Product', 'Amount', False, 5
# Loop through and display top products
for i, (product, amount) in enumerate(top_products.items(), 1):
    print(f"{i}. {product}: ${amount:,.2f}")

# TODO: Regional analysis
print(f"\nRegional Analysis:")
# Group by City and aggregate multiple columns
regional_stats = complete_data.groupby('__________').agg({ # use 'City'
    'Amount': ['__________', '__________', '__________'], # use 'sum', 'mean', 'count'
    'Customer_Rating': '__________' # use 'mean'
}).round(2)

# Flatten column names
regional_stats.columns = ['_'.join(col).strip() for col in regional_stats.columns]
print(regional_stats)

print(f"\n🎉 All visualization exercises completed!")
