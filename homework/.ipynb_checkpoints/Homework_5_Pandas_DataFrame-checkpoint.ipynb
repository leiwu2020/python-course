# %% [markdown]
# # Homework 5: Pandas DataFrame
#
# **Student Name:**
#
# **Student ID:**
#
# **Date:**
#
# ## Assignment Overview
# This homework assignment tests your understanding of Pandas DataFrame data structure and its operations.
#
# ## Learning Objectives
# - Master DataFrame creation and manipulation
# - Perform indexing, selection, and filtering
# - Handle missing values and data cleaning
# - Use DataFrame methods for data analysis
# - Apply data type conversions and sorting
#
# ## Instructions
# 1. Complete all exercises in order
# 2. Run all code cells and ensure they execute without errors
# 3. Answer all written questions thoroughly
# 4. Submit your completed notebook
#
# ---
#
# ## Exercise 1: DataFrame Creation and Basic Operations (20 points)
#
# **Task:** Create Pandas DataFrames and perform basic operations.
#
# **Requirements:**
# - Create DataFrames from different data sources
# - Perform basic operations on DataFrames
# - Use DataFrame indexing and selection
# - Demonstrate DataFrame methods

# %%
# TODO: Complete the following tasks

import pandas as pd
import numpy as np

# 1. Create DataFrames from different data sources
print("=== DATAFRAME CREATION ===")

# Create DataFrame from dictionary
data_dict = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'Age': [25, 30, 35, 28, 32],
    'City': ['New York', 'London', 'Tokyo', 'Paris', 'Sydney'],
    'Salary': [50000, 60000, 70000, 55000, 65000]
}
df1 = ___________ # convert dictionary data_dict to pandas dataframe
print(f"DataFrame from dictionary:\n{df1}")

# TODO: Create DataFrame from list of lists
data_list = [
    ['Alice', 25, 'New York', 50000],
    ['Bob', 30, 'London', 60000],
    ['Charlie', 35, 'Tokyo', 70000],
    ['Diana', 28, 'Paris', 55000],
    ['Eve', 32, 'Sydney', 65000]
]
columns = ['Name', 'Age', 'City', 'Salary']
df2 = __________ # creates a Pandas DataFrame from a list of data (data_list) and explicitly sets the column names using the columns parameter
print(f"\nDataFrame from list of lists:\n{df2}")

# Create DataFrame from NumPy array
np_data = np.random.randint(1, 100, (5, 4))
df3 = ___________ # creates a Pandas DataFrame from a NumPy array (np_data) and assigns the column names 'A', 'B', 'C', and 'D'
print(f"\nDataFrame from NumPy array:\n{df3}")

# 2. Perform basic operations on DataFrames
print(f"\n=== BASIC OPERATIONS ===")

# DataFrame info
print(f"DataFrame shape: {__________}")  # returns a tuple representing the dimensions of the Pandas DataFrame df1
print(f"DataFrame columns: {__________}") # converts the column labels of the DataFrame df1 into a Python list.
print(f"DataFrame index: {_________}")  #  converts the index labels of the DataFrame df1 into a Python list.
print(f"DataFrame dtypes:\n{__________}") # returns the data types of each column in the Pandas DataFrame df1.

# Statistical summary
print(f"\nStatistical summary:")
print(___________) # generates summary statistics of the numeric columns in the DataFrame df1 by default.

# 3. Use DataFrame indexing and selection
print(f"\n=== INDEXING AND SELECTION ===")

# Column selection
print(f"Name column: {_________}")  # selects the column named 'Name' from the DataFrame df1 and returns it as a Pandas Series.
print(f"Age and Salary columns:\n{__________}") # selects multiple columns, specifically 'Age' and 'Salary', from the DataFrame df1 and returns them as a new DataFrame

# Row selection
print(f"\nFirst row:\n{_________}") # selects the first row of the DataFrame df1 based on its integer position (index 0) and returns it as a Pandas Series
print(f"First 3 rows:\n{__________}") # selects the first three rows of the DataFrame df1 based on their integer positions (rows at positions 0, 1, and 2) and returns them as a new DataFrame.

# Label-based selection
print(f"\nLabel-based selection:")
print(f"Row 0:\n{_________}") # selects the row in the DataFrame df1 with the index label 0 and returns it as a Pandas Series.
print(f"Rows 0-2, columns 'Name' and 'Age':\n{__________}") #  elects rows with index labels from 0 to 2 (inclusive) and only the columns 'Name' and 'Age' from the DataFrame df1

# Boolean indexing
print(f"\nBoolean indexing:")
high_salary = __________  # creates a mask named high_salary by checking which rows in the 'Salary' column of DataFrame df1 have values greater than 60,000
print(f"High salary employees:\n{__________}") # filters the DataFrame df1 using the mask high_salary

# 4. Demonstrate DataFrame methods
print(f"\n=== DATAFRAME METHODS ===")

# Data cleaning
print(f"Missing values:\n{_______}") # identify missing (null/NaN) values in your DataFrame df1 and counts how many are in each column.

# Sorting
print(f"\nSorted by Age:\n{_________}") # sorts the DataFrame df1 by the values in the 'Age' column in ascending order
print(f"Sorted by Salary (descending):\n{__________}") # sorts the DataFrame df1 by the values in the 'Salary' column in descending order

# Grouping
print(f"\nGroup by City:\n{__________}") #  Groups the DataFrame df1 by the values in the 'City' column.  For each group (each unique city), it selects the 'Salary' column.  Calculates the mean (average) salary for each city group.

# Adding new columns
df1['Age_Group'] = __________  # applies a function to each value in the 'Age' column of the DataFrame df1, and returns a new Series where: For each age x, if x is less than 30, it returns 'Young'. Otherwise, it returns 'Old'.
print(f"\nDataFrame with Age_Group:\n{df1}")
