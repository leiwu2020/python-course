# %% [markdown]
# # Homework 4: Pandas Series
#
# **Student Name:**
#
# **Student ID:**
#
# **Date:**
#
# ## Assignment Overview
# This homework assignment tests your understanding of Pandas Series data structure and its operations.
#
# ## Learning Objectives
# - Master Pandas Series creation and manipulation
# - Perform indexing and selection operations
# - Handle missing values in Series
# - Use Series methods for data analysis
# - Apply string and date operations
#
# ## Instructions
# 1. Complete all exercises in order
# 2. Run all code cells and ensure they execute without errors
# 3. Answer all written questions thoroughly
# 4. Submit your completed notebook
#
# ---
#
# ## Exercise 1: Series Creation and Basic Operations
#
# **Task:** Create Pandas Series and perform basic operations.
#
# **Requirements:**
# - Create Series from different data sources
# - Perform basic operations on Series
# - Use Series indexing and selection
# - Demonstrate Series methods

# %%
# TODO: Complete the following tasks

import pandas as pd
import numpy as np

# 1. Create Series from different data sources
print("=== SERIES CREATION ===")

# Create Series from list
data_list = [10, 20, 30, 40, 50]
series1 = ___________ # create pandas series from the list
print(f"Series from list:\n{series1}")

# TODO: Create Series with custom index
custom_index = ['A', 'B', 'C', 'D', 'E']
series2 = __________ # create pandas series from data_list with custom index
print(f"\nSeries with custom index:\n{series2}")

# Create Series from dictionary
data_dict = {'Alice': 25, 'Bob': 30, 'Charlie': 35, 'Diana': 28}
series3 = __________ # create pandas series from dictionary data_dict
print(f"\nSeries from dictionary:\n{series3}")

# Create Series from NumPy array
np_array = np.array([1.5, 2.5, 3.5, 4.5, 5.5])
series4 = __________  #  creates a Pandas Series from a NumPy array and assigns a name 'Values' to that Series.
print(f"\nSeries from NumPy array:\n{series4}")

# 2. Perform basic operations on Series
print(f"\n=== BASIC OPERATIONS ===")

# Arithmetic operations
print(f"Series1 + 10:\n{___________}") # add 10 to each element in the series
print(f"Series1 * 2:\n{____________}") # multiply 2 to each element in the series
print(f"Series1 + Series2:\n{______________}") # add each element in series 1 with corresponding element in series 2

# Statistical operations
print(f"\nStatistical operations:")
print(f"Mean: {__________}") #  calculate the mean of the series 1
print(f"Sum: {__________}")  #  calculate the sum of the series 1
print(f"Max: {__________}")  #  calculate the max of the series 1
print(f"Min: {__________}")   #  calculate the min of the series 1
print(f"Std: {__________}")  #  calculate the std of the series 1 and formats the number to 2 decimal places when printing

# 3. Use Series indexing and selection
print(f"\n=== INDEXING AND SELECTION ===")

# Position-based indexing
print(f"First element: {__________}") # print the first element of series 1
print(f"Last element: {__________}")  # print the last element of series 1
print(f"First 3 elements: {__________}")  # print the first 3 elements of series 1

# Label-based indexing
print(f"\nLabel-based indexing:")
print(f"Element 'B': {__________}")  # print the value associated with the label 'B' in the Pandas Series series2
print(f"Elements 'A' to 'C': {__________}")  # slicing in a Pandas Series — and includes both the start and end labels ('A' to 'C')

# Boolean indexing
print(f"\nBoolean indexing:")
mask = ___________ # create mask where series value > 25
print(f"Elements > 25: {____________}") # select only the elements where the mask is True

# 4. Demonstrate Series methods
print(f"\n=== SERIES METHODS ===")

# String methods (if applicable)
text_series = pd.Series(['apple', 'banana', 'cherry', 'date'])
print(f"Original: {text_series}")
print(f"Uppercase: {_________}") # converts all the strings in a Pandas Series text_series to uppercase.
print(f"Length: {_________}") # alculates the length (number of characters) of each string in the Pandas Series text_series

# Mathematical methods
print(f"\nMathematical methods:")
print(f"Absolute values: {__________}") #  creates a Pandas Series from the list [-1, -2, 3, -4] and returns the absolute value of each element.
print(f"Square root: {__________}")  # creates a Pandas Series from the list [4, 9, 16, 25] and applies the NumPy sqrt (square root) function to each element in the Pandas Series

# Sorting
print(f"\nSorting:")
print(f"Sorted by values: {__________}") # sorts the values in the Pandas Series series1 in ascending order and returns a new Series with the sorted values
print(f"Sorted by index: {__________}")  # sorts the Pandas Series series2 based on its index labels in ascending order.
