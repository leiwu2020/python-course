# %% [markdown]
# # Homework 3: Numerical Data Analysis with NumPy
#
# **Student Name:**
#
# **Student ID:**
#
# **Date:**
#
# ## Assignment Overview
# This homework assignment tests your understanding of NumPy library for numerical computing, array operations, and mathematical functions.
#
# ## Learning Objectives
# - Master NumPy array creation and manipulation
# - Perform mathematical operations on arrays
# - Use NumPy's statistical functions
# - Implement linear algebra operations
# - Handle missing data and array reshaping
#
# ## Instructions
# 1. Complete all exercises in order
# 2. Run all code cells and ensure they execute without errors
# 3. Answer all written questions thoroughly
# 4. Submit your completed notebook
#
# ---
#
# ## Exercise 1: Array Creation and Basic Operations (20 points)
#
# **Task:** Create NumPy arrays and perform basic operations.
#
# **Requirements:**
# - Create arrays using different methods
# - Perform element-wise operations
# - Use array indexing and slicing
# - Demonstrate broadcasting

# %%
# TODO: Complete the following tasks

# Import the NumPy library and give it the alias 'np' for easier use
import numpy as np

# 1. Create arrays using different methods
# Print a header to indicate the start of array creation examples
print("=== ARRAY CREATION ===")

# Create arrays from lists
# Create a Python list containing integers from 1 to 5
list_data = [1, 2, 3, 4, 5]
# Convert the Python list to a NumPy array using np.array()
arr1 = _______  # convert list to numpy array
# Print the array created from the list
print(f"From list: {arr1}")
# Print the type of the array object (numpy.ndarray)
print(f"Type: {type(arr1)}")
# Print the data type of the elements in the array (int64 by default)
print(f"Data type: {arr1.dtype}")

# TODO: Create a 2D array from nested lists
# Create a nested list representing a 3x3 matrix
matrix_data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# Convert the nested list to a 2D NumPy array
arr2d = _______ # convert 2D list to numpy array
# Print the 2D array with newline for better formatting
print(f"\n2D array:\n{arr2d}")
# Print the shape of the array (rows, columns)
print(f"Shape: {_______}")

# TODO: Create arrays with specific data types
# Create a NumPy array with 32-bit integer data type
arr_int = _______ # convert list [1,2,3] to int32 numpy array
# Create a NumPy array with 64-bit float data type
arr_float = _______ # convert list [1,2,3] to float64 numpy array
# Print the integer array with its data type
print(f"\nInteger array: {arr_int}, dtype: {arr_int.dtype}")
# Print the float array with its data type
print(f"Float array: {arr_float}, dtype: {arr_float.dtype}")

# Array creation functions
# Create a 1D array of 5 zeros using np.zeros()
zeros = _______ # create 5 x 5 numpy array with all zeros
# Create a 3x4 array of ones using np.ones() with tuple for shape
ones = _______  # create 3 x 4 numpy array with all ones
# Create a 2x3 array filled with the value 7 using np.full()
full = np.full((2, 3), 7) # create 2 x 3 numpy array with full 7s
# Print the zeros array
print(f"\nZeros: {zeros}")
# Print the ones array with newline for better formatting
print(f"Ones:\n{ones}")
# Print the full array with newline for better formatting
print(f"Full (7s):\n{full}")

# Range arrays
# Create an array with values from 0 to 10 (exclusive) with step 2
range_arr = _______ # create range [0, 10) with internal 2
# Create an array with 5 evenly spaced values from 0 to 1 (inclusive)
linspace_arr = _______  # create 5 evenly spaced numbers over the interval from 0 to 1, inclusive.
# Print the arange array
print(f"\nArange: {range_arr}")
# Print the linspace array
print(f"Linspace: {linspace_arr}")

# Random arrays
# Set the random seed to 42 for reproducible results
np.random.seed(42)  # For reproducible results
# Create a 3x3 array with random values between 0 and 1
random_arr = _______ #  create random 3 x 3 array
# Print the random array with newline for better formatting
print(f"\nRandom array:\n{random_arr}")

# Identity matrix
# Create a 3x3 identity matrix (1s on diagonal, 0s elsewhere)
identity = np.eye(3) # creates a 3×3 identity matrix
# Print the identity matrix with newline for better formatting
print(f"\nIdentity matrix:\n{identity}")

# %%
# 2. Perform element-wise operations
print("\n=== ELEMENT-WISE OPERATIONS ===")

# Create sample arrays
arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([5, 6, 7, 8])

print(f"Array 1: {arr1}")
print(f"Array 2: {arr2}")

# TODO: Perform arithmetic operations
print(f"\nArithmetic operations:")
print(f"Addition: {________}") # add the two array together
print(f"Subtraction: {_________}") # subtract array 2 from array 1
print(f"Multiplication: {_________}") # multiply the two arrays
print(f"Division: {________}") # divide array 1 by array 2
print(f"Power: {_______}") # squares each element of the array

# Broadcasting examples
print(f"\n--- Broadcasting Examples ---")

# Scalar broadcasting
scalar = 10
print(f"Array + scalar: {________}")  # add array 1 with scaler
print(f"Array * scalar: {________}")  # multiply array 1 with scaler

# Different shapes
arr_2d = __________ # use number 1 to 6 to create a 2 x 3 numpy array
arr_1d = __________ # use number 10, 20, 30 to create a 1 x 3 numpy array

print(f"\n2D array:\n{arr_2d}")
print(f"1D array: {arr_1d}")
print(f"2D + 1D (broadcasting):\n{arr_2d + arr_1d}")

# TODO: Create more broadcasting examples
arr_col = ____________ # creates a 2D NumPy array with 3 rows and 1 column with number 1, 2, 3
arr_row = ____________ # creates a 2D NumPy array with 1 row and 3 column with number 10, 20, 30

print(f"\nColumn array:\n{arr_col}")
print(f"Row array: {arr_row}")
print(f"Column + Row (broadcasting):\n{arr_col + arr_row}")
